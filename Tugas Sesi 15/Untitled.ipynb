# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

bulan = ['Januari', 'Februari', 'Maret', 'April', 'Mei', 'Juni', 'Juli', 'Agustus', 'September', 'Oktober', 'November', 'Desember']

#Pengeluaran antara 500.000 - 2.000.000

minggu_1 = np.random.randint(500000, 2000001, 12)
minggu_2 = np.random.randint(500000, 2000001, 12)
minggu_3 = np.random.randint(500000, 2000001, 12)
minggu_4 = np.random.randint(500000, 2000001, 12)

data ={
    'Bulan' : bulan,
    'Minggu_1' : minggu_1,
    'Minggu_2' : minggu_2,
    'Minggu_3' : minggu_3,
    'Minggu_4' : minggu_4,
}

df = pd.DataFrame(data)

df['Total_Pengeluaran'] = df[['Minggu_1','Minggu_2', 'Minggu_3', 'Minggu_4']].sum(axis=1)
df
# Out:
#         Bulan  Minggu_1  Minggu_2  Minggu_3  Minggu_4  Total_Pengeluaran
# 0     Januari   1399546   1892690    668863   1242626            5203725
# 1    Februari    715095    627161   1474767    626701            3443724
# 2       Maret   1354350    816306    621392   1155069            3947117
# 3       April   1999366   1485846   1397925   1736398            6619535
# 4         Mei   1857951   1929288    795020   1952549            6534808
# 5        Juni   1146891    997076   1623216   1118654            4885837
# 6        Juli    636852   1310381    985123   1136017            4068373
# 7     Agustus   1534171   1165725   1554093   1028343            5282332
# 8   September    787121   1007415    866971   1603972            4265479
# 9     Oktober   1716393   1829461   1777373   1211695            6534922
# 10   November   1328589   1303025   1277496    923802            4832912
# 11   Desember   1943464   1880380   1012140   1266085            6102069

# %%
#Total pengeluaran Per Bulan

plt.figure(figsize=(12,6)) #Canvas Dengan Ukuran width, height (inch)
plt.title('Total Pengeluaran Per Bulan')
plt.bar(df['Bulan'], df['Total_Pengeluaran'], color='magenta')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.ylabel("Rupiah")
plt.show()

# %%
#Scatter Plot untuk analisa data pengeluaran per minggu per bulan
plt.figure(figsize=(12,6))
for minggu in ['Minggu_1', 'Minggu_2', 'Minggu_3', 'Minggu_4']:
    plt.plot(df['Bulan'], df[minggu], marker='o', label=minggu)
        
plt.title("Pengeluaran Per Minggu")
plt.xlabel('Bulan')
plt.ylabel('Pengeluaran (Rupiah)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Pie Chart --> Prosentase
plt.figure(figsize = (10,10))
plt.pie(df['Total_Pengeluaran'], labels=df['Bulan'],startangle=90,autopct='%1.1f%%')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

df['Bulan_Angka'] = np.arange(1, 13)


x = df[['Bulan_Angka']]
y = df['Total_Pengeluaran']

model = LinearRegression()
model.fit(x,y)

prediksi = model.predict([[13]])[0]
print(f"Hasil Prediksi adalah :{prediksi:,.0f}")
# Out:
# Hasil Prediksi adalah :5,692,356
# C:\Users\KOMPUTER JARKOM 9\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
